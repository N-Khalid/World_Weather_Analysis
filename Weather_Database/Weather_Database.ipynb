# %%
# Importing modules
import random
import pandas as pd
import timeit
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import json
import requests

from datetime import datetime
from config import weather_api_key

# %%
# Creating 2000 random coordinate combinations(latitude/longitude) and creating a zip
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Putting the coordinate combinations into a list and viewing the list
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(-66.66767949511794, -55.648488817701406), (67.19579256825443, 162.7309704967318), (78.70417581359413, 64.33907934733887), (-18.454610889092947, 144.64019099566553), (1.9867240210645463, 24.469819081837556), (-59.70082705161538, -7.829126098293045), (-81.72464327974987, 145.08799532500353), (54.30705894779405, 64.75327600246726), (9.038995024508907, 45.92515371154559), (0.2757166240076998, -63.12555200884515), (40.406115268221356, -37.30780311386545), (-33.20161375000946, 83.53257303524305), (-76.83554748955066, -153.100539337471), (14.01798986258214, 137.28716452542182), (-23.039682580361827, -54.406052845435056), (-51.752257547021756, -124.99182514319168), (43.45050324643856, -167.12171725506246), (-52.94457274432563, 120.03317510762446), (-58.13787307769154, 127.30180668589668), (-1.3919214551650754, -153.4337351150341), (-19.757636983391308, 116.89074544812166), (-23.39201753244373, -173.56966527224668), (-51.60826581055039, -103.69407503506346), (67.18609026337259, 63.098510216005536), (21.75055922179375, 170.78033984570652), (6.89850206251549, -3.7461784051085942), (-62.72913184943998, 113.14674689010513), (39.47701782291904, 76.94710069062842), (1.5156862361761938, -39.67895152101309), (-17.11029367031628, 53.659292353943016), (-3.6579331215844206, -6.663306173946211), (-40.99084681059847, -111.55757821014247), (-51.59012441878444, -161.28295961102924), (-38.902024127638384, -22.51997236321472), (8.428096951955808, 130.87560551081697), (-52.05762279660591, 53.480295828933265), (-83.88136524150342, -137.65082998982268), (68.81003344242703, 95.3581974749178), (79.58280801373738, 104.55038551668372), (-4.645183329992747, -19.662767774596063), (-85.00717151938768, -147.20363969902624), (11.230626899760267, -97.46947207857504), (-54.387534246801884, 171.41414330948936), (-1.724722618439074, 59.351832479291346), (74.2111000077484, -10.720359089013556), (-81.78096570605379, -80.32459580281056), (29.647311270966327, -59.48491756976969), (-61.64201593913081, 32.4230939073083), (32.59958626254169, -178.4250521489979), (-30.26319964519623, 146.42955121604115), (2.6318698720042164, -167.849059349959), (-75.71980117796578, -164.0332857712704), (81.8860050233763, 121.04969626951072), (-18.46848843480211, 66.44962624434376), (-46.4254729651065, -127.2556885449888), (-60.28435862281823, 148.9186626759095), (-66.73617803136597, 84.19419833838856), (34.49307320750705, -132.4186765535055), (-56.65286675907081, -132.41637336919547), (89.1765701189347, 79.44074535954064), (-14.745120223925653, 149.70696863587398), (72.09552248640861, 84.61518346400283), (-47.86805300610323, 174.92756997201383), (-32.63311577532844, 63.797499713931046), (11.591166783696494, -168.33189700175768), (-80.93270968570363, -168.34946981784907), (61.48764411573953, 144.08473696175923), (-36.45088494423963, 164.6328694554329), (89.69135283017349, -50.593808523479794), (-53.99801187349444, -142.53078317483843), (-26.87941924077161, -22.604186601103606), (49.741212634342304, 87.96735969500168), (-43.90151890556787, -27.55538353963476), (-64.81710523922051, 57.21260174702431), (-17.167644757699406, 159.09535012847965), (-22.357573442655436, -90.7273787242578), (-2.127712702763077, -23.640738103521414), (-61.53730053509305, 65.6108075423424), (-9.491407336124311, 103.40222584259914), (-39.83028249400319, 165.3822699929495), (-69.11816446414339, -169.1694271596165), (50.84175463154517, 126.58252379633427), (10.515124606898127, -40.50475063520818), (85.09540875150057, 5.869913828208297), (80.406907986678, 25.721595062418572), (-71.31644482307331, -177.440628414152), (-5.9531995417183055, -3.7254088327190686), (-1.9069661401777154, 51.2685910135653), (9.34238076760434, -174.2306843837954), (67.72180337862792, -176.68825573135453), (12.541813188113451, -128.1010684860816), (-88.96405540404983, 156.01181782448822), (-40.70098140872791, -117.93504709067335), (11.022324563061417, -31.57535954031215), (33.986983029111556, 56.561210778983224), (-78.20858742804155, -18.0641260021 ...

# %%
#Creating a cities list, finding the nearest city and if the city is a 'unique' city, it will be added to the cities list 
cities = []

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
#API Call with OpenWeatherMap API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieving Latitude and longitude, Max temperature, % humidity, % cloudiness, Wind speed, Weather description from API call

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | cherskiy
# Processing Record 3 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 1 | atherton
# Processing Record 5 of Set 1 | buta
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | zverinogolovskoye
# Processing Record 9 of Set 1 | odweyne
# Processing Record 10 of Set 1 | barcelos
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | bambous virieux
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | airai
# Processing Record 15 of Set 1 | navirai
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | bethel
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | mount gambier
# Processing Record 20 of Set 1 | faanui
# Processing Record 21 of Set 1 | karratha
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | castro
# Processing Record 24 of Set 1 | zapolyarnyy
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | daoukro
# Processing Record 27 of Set 1 | kashi
# Processing Record 28 of Set 1 | acarau
# Processing Record 29 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 30 of Set 1 | harper
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | arraial do cabo
# Processing Record 33 of Set 1 | kloulklubed
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | tura
# Processing Record 36 of Set 1 | khatanga
# Processing Record 37 of Set 1 | georgetown
# Processing Record 38 of Set 1 | pochutla
# Processing Record 39 of Set 1 | kaitangata
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | husavik
# Processing Record 42 of Set 1 | saint george
# Processing Record 43 of Set 1 | port elizabeth
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | dubbo
# Processing Record 46 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | quatre cocos
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | fortuna
# Processing Record 1 of Set 2 | dikson
# Processing Record 2 of Set 2 | samarai
# Processing Record 3 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 2 | waitati
# Processing Record 5 of Set 2 | souillac
# Processing Record 6 of Set 2 | okhotsk
# Processing Record 7 of Set 2 | ahipara
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | vila velha
# Processing Record 10 of Set 2 | aktash
# Processing Record 11 of Set 2 | poum
# Processing Record 12 of Set 2 | pisco
# Processing Record 13 of Set 2 | labuhan
# Processing Record 14 of Set 2 | te anau
# Processing Record 15 of Set 2 | heihe
# Processing Record 16 of Set 2 | carutapera
# Processing Record 17 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 2 | honningsvag
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | egvekinot
# Processing Record 21 of Set 2 | constitucion
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | sao filipe
# Processing Record 24 of Set 2 | tabas
# Processing Record 25 of Set 2 | punta arenas
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | hasaki
# Processing Record 28 of Set 2 | pali
# Processing Record 29 of Set 2 | port alfred
# Processing Record 30 of Set 2 | coquimbo
# Processing Record 31 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 2 | ornskoldsvik
# Processing Record 34 of Set 2 | tabialan
# City not found. Skipping...
# Processing Record 35 of Set 2 | carnarvon
# Processing Record 36 of Set 2 | bandarbeyla
# Processing Record 37 of Set 2 | hulan ergi
# Processing Record 38 of Set 2 | ivdel
# Processing Record 39 of Set 2 | asfi
# Processing Record 40 of Set 2 | bredasdorp
# Processing Record 41 of Set 2 | koslan
# Processing Record 42 of Set 2 | portland
# Processing Record 43 of Set 2 | san patricio
# Processing Record 44 of Set 2 | mar del plata
# Processing Record 45 of Set 2 | wairoa
# Processing Record 46 of Set 2 | rawlins
# Processing Record 47 of Set 2 | mandalgovi
# Processing Record 48 of Set 2 | saldanha
# Processing Record 49 of Set 2 | tiksi
# Processing Record 50 of Set 2 | hongjiang
# Processing Record 1 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 2 of Set 3 | hilo
# Processing Record 3 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 3 | provideniya
# Processing Record 5 of Set 3 | nouadhibou
# Processing Record 6 of Set 3 | soimi
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | kushmurun
# Processing Record 9 of Set 3 | sorland
# Processing Record 10 of Set 3 | nikolskoye
# Processing Record 11 of Set 3 | saint-philippe
# Processing Record 12 of Set 3 | yellowknife
# Processing Record 13 of Set 3 | tasiilaq
# Processing Record 14 of Set 3 | giyon
# Processing Record 15 of Set 3 | mykhaylivka
# Processing Record 16 of Set 3 | lorengau
# Processing Record 17 of Set 3 | atuona
# Processing Record 18 of Set 3 | pitimbu
# Processing Record 19 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 3 | port blair
# Processing Record 22 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 3 | ewa beach
# Processing Record 24 of Set 3 | hithadhoo
# Processing Record 25 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 3 | coos bay
# Processing Record 27 of Set 3 | port hawkesbury
# Processing Record 28 of Set 3 | majene
# Processing Record 29 of Set 3 | ondjiva
# Processing Record 30 of Set 3 | kruisfontein
# Processing Record 31 of Set 3 | bilibino
# Processing Record 32 of Set 3 | mana
# Processing Record 33 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 3 | emba
# Processing Record 35 of Set 3 | pevek
# Processing Record 36 of Set 3 | kavaratti
# Processing Record 37 of Set 3 | oranjemund
# Processing Record 38 of Set 3 | bambanglipuro
# Processing Record 39 of Set 3 | aklavik
# Processing Record 40 of Set 3 | tomari
# Processing Record 41 of Set 3 | plettenberg bay
# Processing Record 42 of Set 3 | barrow
# Processing Record 43 of Set 3 | nieuw nickerie
# Processing Record 44 of Set 3 | malabo
# Processing Record 45 of Set 3 | dingle
# Processing Record 46 of Set 3 | doha
# Processing Record 47 of Set 3 | ponta do sol
# Processing Record 48 of Set 3 | new norfolk
# Processing Record 49 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 50 of Set 3 | bloomfield
# Processing Record 1 of Set 4 | charters towers
# Processing Record 2 of Set 4 | sioux lookout
# Processing Record 3 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 4 | chumikan
# Processing Record 5 of Set 4 | porto novo
# Processing Record 6 of Set 4 | east london
# Processing Record 7 of Set 4 | hamilton
# Processing Record 8 of Set 4 | livny
# Processing Record 9 of Set 4 | margate
# Processing Record 10 of Set 4 | acapulco
# Processing Record 11 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 4 | laguna
# Processing Record 13 of Set 4 | fonte boa
# Processing Record 14 of Set 4 | los llanos de aridane
# Processing Record 15 of Set 4 | longyearbyen
# Processing Record 16 of Set 4 | esperanza
# Processing Record 17 of Set 4 | mindelo
# Processing Record 18 of Set 4 | bathsheba
# Processing Record 19 of Set 4 | chernyshevskiy
# Processing Record 20 of Set 4 | mehamn
# Processing Record 21 of Set 4 | shirokiy
# Processing Record 22 of Set 4 | padang
# Processing Record 23 of Set 4 | kahului
# Processing Record 24 of Set 4 | caravelas
# Processing Record 25 of Set 4 | ashland
# Processing Record 26 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 27 of Set 4 | salalah
# Processing Record 28 of Set 4 | rocha
# Processing Record 29 of Set 4 | yichang
# Processing Record 30 of Set 4 | mumford
# Processing Record 31 of Set 4 | san pedro
# Processing Record 32 of Set 4 | acin
# City not found. Skipping...
# Processing Record 33 of Set 4 | lompoc
# Processing Record 34 of Set 4 | mahebourg
# Processing Record 35 of Set 4 | mayor pablo lagerenza
# Processing Record 36 of Set 4 | popondetta
# Processing Record 37 of Set 4 | esperance
# Processing Record 38 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 39 of Set 4 | nanortalik
# Processing Record 40 of Set 4 | lagos
# Processing Record 41 of Set 4 | cabo san lucas
# Processing Record 42 of Set 4 | dunedin
# Processing Record 43 of Set 4 | korla
# Processing Record 44 of Set 4 | ishinomaki
# Processing Record 45 of Set 4 | marolambo
# Processing Record 46 of Set 4 | talnakh
# Processing Record 47 of Set 4 | port-cartier
# Processing Record 48 of Set 4 | atar
# Processing Record 49 of Set 4 | asau
# Processing Record 50 of Set 4 | kodinsk
# Processing Record 1 of Set 5 | loubomo
# Processing Record 2 of Set 5 | rio branco
# Processing Record 3 of Set 5 | dwarka
# Processing Record 4 of Set 5 | richards bay
# Processing Record 5 of Set 5 | ardakan
# Processing Record 6 of Set 5 | lancaster
# Processing Record 7 of Set 5 | pacific grove
# Processing Record 8 of Set 5 | rudsar
# Processing Record 9 of Set 5 | norman wells
# Processing Record 10 of Set 5 | udachnyy
# Processing Record 11 of Set 5 | coruripe
# Processing Record 12 of Set 5 | gravdal
# Processing Record 13 of Set 5 | meulaboh
# Processing Record 14 of Set 5 | ola
# Processing Record 15 of Set 5 | lerwick
# Processing Record 16 of Set 5 | niquero
# Processing Record 17 of Set 5 | puerto ayora
# Processing Record 18 of Set 5 | abdulino
# Processing Record 19 of Set 5 | obo
# Processing Record 20 of Set 5 | beira
# Processing Record 21 of Set 5 | batemans bay
# Processing Record 22 of Set 5 | yulara
# Processing Record 23 of Set 5 | denpasar
# Processing Record 24 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 5 | cidreira
# Processing Record 26 of Set 5 | buinsk
# Processing Record 27 of Set 5 | grindavik
# Processing Record 28 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 5 | torbay
# Processing Record 30 of Set 5 | tera
# Processing Record 31 of Set 5 | tuatapere
# Processing Record 32 of Set 5 | qaanaaq
# Processing Record 33 of Set 5 | geraldton
# Processing Record 34 of Set 5 | sragen
# Processing Record 35 of Set 5 | marv dasht
# City not found. Skipping...
# Processing Record 36 of Set 5 | tuktoyaktuk
# Processing Record 37 of Set 5 | lensk
# Processing Record 38 of Set 5 | esna
# Processing Record 39 of Set 5 | hofn
# Processing Record 40 of Set 5 | yumen
# Processing Record 41 of Set 5 | katsuura
# Processing Record 42 of Set 5 | anadyr
# Processing Record 43 of Set 5 | narsaq
# Processing Record 44 of Set 5 | bengkulu
# Processing Record 45 of Set 5 | salto
# Processing Record 46 of Set 5 | namibe
# Processing Record 47 of Set 5 | naples
# Processing Record 48 of Set 5 | palanga
# Processing Record 49 of Set 5 | puerto escondido
# Processing Record 50 of Set 5 | belgaum
# Processing Record 1 of Set 6 | rawson
# Processing Record 2 of Set 6 | oktyabrskoye
# Processing Record 3 of Set 6 | rio gallegos
# Processing Record 4 of Set 6 | marihatag
# Processing Record 5 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 6 of Set 6 | zhuozhou
# City not found. Skipping...
# Processing Record 7 of Set 6 | muros
# Processing Record 8 of Set 6 | port hardy
# Processing Record 9 of Set 6 | svetlyy
# Processing Record 10 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 6 | saint-ambroise
# Processing Record 12 of Set 6 | zhigalovo
# Processing Record 13 of Set 6 | chapais
# Processing Record 14 of Set 6 | agotnes
# Processing Record 15 of Set 6 | cap malheureux
# Processing Record 16 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 6 | vostok
# Processing Record 18 of Set 6 | krasnoselkup
# Processing Record 19 of Set 6 | lakatoro
# Processing Record 20 of Set 6 | menongue
# Processing Record 21 of Set 6 | alta floresta
# Processing Record 22 of Set 6 | nome
# Processing Record 23 of Set 6 | shihezi
# Processing Record 24 of Set 6 | traverse city
# Processing Record 25 of Set 6 | aswan
# Processing Record 26 of Set 6 | marrakesh
# Processing Record 27 of Set 6 | abnub
# Processing Record 28 of Set 6 | vilhena
# Processing Record 29 of Set 6 | lamu
# Processing Record 30 of Set 6 | sorong
# Processing Record 31 of Set 6 | erzin
# Processing Record 32 of Set 6 | goderich
# Processing Record 33 of Set 6 | sabang
# Processing Record 34 of Set 6 | high level
# Processing Record 35 of Set 6 | bocaiuva
# Processing Record 36 of Set 6 | warrington
# Processing Record 37 of Set 6 | grand forks
# Processing Record 38 of Set 6 | palana
# Processing Record 39 of Set 6 | haines junction
# Processing Record 40 of Set 6 | sao mateus
# Processing Record 41 of Set 6 | deputatskiy
# Processing Record 42 of Set 6 | recco
# Processing Record 43 of Set 6 | vieux-habitants
# Processing Record 44 of Set 6 | kaeo
# Processing Record 45 of Set 6 | alofi
# Processing Record 46 of Set 6 | natal
# Processing Record 47 of Set 6 | qarqin
# Processing Record 48 of Set 6 | preobrazheniye
# Processing Record 49 of Set 6 | beisfjord
# Processing Record 50 of Set 6 | grand gaube
# Processing Record 1 of Set 7 | tarakan
# Processing Record 2 of Set 7 | isangel
# Processing Record 3 of Set 7 | road town
# Processing Record 4 of Set 7 | hun
# Processing Record 5 of Set 7 | anori
# Processing Record 6 of Set 7 | cayenne
# Processing Record 7 of Set 7 | zholymbet
# Processing Record 8 of Set 7 | pestovo
# Processing Record 9 of Set 7 | vardo
# Processing Record 10 of Set 7 | matay
# Processing Record 11 of Set 7 | ilulissat
# Processing Record 12 of Set 7 | pemangkat
# Processing Record 13 of Set 7 | coromandel
# Processing Record 14 of Set 7 | el carmen
# Processing Record 15 of Set 7 | mahajanga
# Processing Record 16 of Set 7 | baykit
# Processing Record 17 of Set 7 | chokurdakh
# Processing Record 18 of Set 7 | rundu
# Processing Record 19 of Set 7 | bairiki
# Processing Record 20 of Set 7 | vestmannaeyjar
# Processing Record 21 of Set 7 | santa maria
# Processing Record 22 of Set 7 | katangli
# Processing Record 23 of Set 7 | pervomayskiy
# Processing Record 24 of Set 7 | port lincoln
# Processing Record 25 of Set 7 | varzea da palma
# Processing Record 26 of Set 7 | itarare
# Processing Record 27 of Set 7 | kotelnikovo
# Processing Record 28 of Set 7 | muravlenko
# Processing Record 29 of Set 7 | fairview
# Processing Record 30 of Set 7 | fukue
# Processing Record 31 of Set 7 | rio cuarto
# Processing Record 32 of Set 7 | hami
# Processing Record 33 of Set 7 | viedma
# Processing Record 34 of Set 7 | rio cauto
# Processing Record 35 of Set 7 | nadaun
# Processing Record 36 of Set 7 | srednekolymsk
# Processing Record 37 of Set 7 | lima
# Processing Record 38 of Set 7 | weligama
# Processing Record 39 of Set 7 | krosno odrzanskie
# Processing Record 40 of Set 7 | ostrovnoy
# Processing Record 41 of Set 7 | ketchikan
# Processing Record 42 of Set 7 | khash
# Processing Record 43 of Set 7 | hope
# Processing Record 44 of Set 7 | taltal
# Processing Record 45 of Set 7 | kananga
# Processing Record 46 of Set 7 | yeniseysk
# Processing Record 47 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 48 of Set 7 | gornopravdinsk
# Processing Record 49 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 7 | tooele
# Processing Record 1 of Set 8 | lavrentiya
# Processing Record 2 of Set 8 | tadine
# Processing Record 3 of Set 8 | bilma
# Processing Record 4 of Set 8 | henties bay
# Processing Record 5 of Set 8 | lubumbashi
# Processing Record 6 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 8 | lazaro cardenas
# Processing Record 8 of Set 8 | biloela
# Processing Record 9 of Set 8 | sur
# Processing Record 10 of Set 8 | ibirataia
# Processing Record 11 of Set 8 | mecca
# Processing Record 12 of Set 8 | igarka
# Processing Record 13 of Set 8 | lexington park
# Processing Record 14 of Set 8 | sechura
# Processing Record 15 of Set 8 | livingston
# Processing Record 16 of Set 8 | kodiak
# Processing Record 17 of Set 8 | chuy
# Processing Record 18 of Set 8 | montepuez
# Processing Record 19 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 8 | santa cruz
# Processing Record 21 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 22 of Set 8 | juba
# Processing Record 23 of Set 8 | waingapu
# Processing Record 24 of Set 8 | the valley
# Processing Record 25 of Set 8 | iqaluit
# Processing Record 26 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 8 | yazman
# Processing Record 28 of Set 8 | thenzawl
# Processing Record 29 of Set 8 | mabaruma
# Processing Record 30 of Set 8 | dong hoi
# Processing Record 31 of Set 8 | waw
# Processing Record 32 of Set 8 | merauke
# Processing Record 33 of Set 8 | havoysund
# Processing Record 34 of Set 8 | wanxian
# Processing Record 35 of Set 8 | lasa
# Processing Record 36 of Set 8 | talaya
# Processing Record 37 of Set 8 | beloha
# Processing Record 38 of Set 8 | nyurba
# Processing Record 39 of Set 8 | riyadh
# Processing Record 40 of Set 8 | cartagena del chaira
# Processing Record 41 of Set 8 | san fernando
# Processing Record 42 of Set 8 | silvino lobos
# Processing Record 43 of Set 8 | hobyo
# Processing Record 44 of Set 8 | port-gentil
# Processing Record 45 of Set 8 | seaford
# Processing Record 46 of Set 8 | turukhansk
# Processing Record 47 of Set 8 | halifax
# Processing Record 48 of Set 8 | agadez
# Processing Record 49 of Set 8 | dakar
# Processing Record 50 of Set 8 | kutum
# Processing Record 1 of Set 9 | lata
# Processing Record 2 of Set 9 | mehtar lam
# Processing Record 3 of Set 9 | vestmanna
# Processing Record 4 of Set 9 | nioro
# Processing Record 5 of Set 9 | gagnoa
# Processing Record 6 of Set 9 | casino
# Processing Record 7 of Set 9 | mazamari
# Processing Record 8 of Set 9 | nanchang
# Processing Record 9 of Set 9 | fort wellington
# Processing Record 10 of Set 9 | sibolga
# Processing Record 11 of Set 9 | marsh harbour
# Processing Record 12 of Set 9 | capilla de guadalupe
# Processing Record 13 of Set 9 | namatanai
# Processing Record 14 of Set 9 | leningradskiy
# Processing Record 15 of Set 9 | imeni zhelyabova
# Processing Record 16 of Set 9 | severo-kurilsk
# Processing Record 17 of Set 9 | caceres
# Processing Record 18 of Set 9 | oldenzaal
# Processing Record 19 of Set 9 | vaitape
# Processing Record 20 of Set 9 | churapcha
# Processing Record 21 of Set 9 | bonfim
# Processing Record 22 of Set 9 | hengyang
# Processing Record 23 of Set 9 | klaksvik
# Processing Record 24 of Set 9 | santiago
# Processing Record 25 of Set 9 | aketi
# Processing Record 26 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 9 | piacabucu
# Processing Record 28 of Set 9 | cabedelo
# Processing Record 29 of Set 9 | ruteng
# Processing Record 30 of Set 9 | sola
# Processing Record 31 of Set 9 | ust-ilimsk
# Processing Record 32 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 33 of Set 9 | rairangpur
# Processing Record 34 of Set 9 | nanakuli
# Processing Record 35 of Set 9 | vuktyl
# Processing Record 36 of Set 9 | tamiahua
# Processing Record 37 of Set 9 | genhe
# Processing Record 38 of Set 9 | noumea
# Processing Record 39 of Set 9 | moroni
# Processing Record 40 of Set 9 | bonavista
# Processing Record 41 of Set 9 | kailua
# Processing Record 42 of Set 9 | opuwo
# Processing Record 43 of Set 9 | broome
# Processing Record 44 of Set 9 | invermere
# Processing Record 45 of Set 9 | chengmai
# City not found. Skipping...
# Processing Record 46 of Set 9 | raga
# Processing Record 47 of Set 9 | lebu
# Processing Record 48 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 49 of Set 9 | san cristobal
# Processing Record 50 of Set 9 | walvis bay
# Processing Record 1 of Set 10 | fairbanks
# Processing Record 2 of Set 10 | sokol
# Processing Record 3 of Set 10 | yar-sale
# Processing Record 4 of Set 10 | lukulu
# Processing Record 5 of Set 10 | nagornskiy
# Processing Record 6 of Set 10 | taksimo
# Processing Record 7 of Set 10 | xifeng
# Processing Record 8 of Set 10 | eyl
# Processing Record 9 of Set 10 | shingu
# Processing Record 10 of Set 10 | ban nahin
# Processing Record 11 of Set 10 | maralal
# Processing Record 12 of Set 10 | saint anthony
# Processing Record 13 of Set 10 | marawi
# Processing Record 14 of Set 10 | kiunga
# Processing Record 15 of Set 10 | bandipur
# Processing Record 16 of Set 10 | tshane
# Processing Record 17 of Set 10 | zyryanka
# Processing Record 18 of Set 10 | college
# Processing Record 19 of Set 10 | upington
# Processing Record 20 of Set 10 | surt
# Processing Record 21 of Set 10 | luderitz
# Processing Record 22 of Set 10 | chicama
# Processing Record 23 of Set 10 | rottenmann
# Processing Record 24 of Set 10 | sinnamary
# Processing Record 25 of Set 10 | abalak
# Processing Record 26 of Set 10 | mount isa
# Processing Record 27 of Set 10 | bela
# Processing Record 28 of Set 10 | vila franca do campo
# Processing Record 29 of Set 10 | aguilas
# Processing Record 30 of Set 10 | skelleftea
# Processing Record 31 of Set 10 | soyo
# Processing Record 32 of Set 10 | merrill
# Processing Record 33 of Set 10 | pangnirtung
# Processing Record 34 of Set 10 | estelle
# Processing Record 35 of Set 10 | freeport
# Processing Record 36 of Set 10 | benguela
# Processing Record 37 of Set 10 | waipawa
# Processing Record 38 of Set 10 | pascagoula
# Processing Record 39 of Set 10 | hensall
# Processing Record 40 of Set 10 | petrila
# Processing Record 41 of Set 10 | ouallam
# Processing Record 42 of Set 10 | loa janan
# Processing Record 43 of Set 10 | ancud
# Processing Record 44 of Set 10 | bud
# Processing Record 45 of Set 10 | nizwa
# Processing Record 46 of Set 10 | avera
# Processing Record 47 of Set 10 | tiarei
# Processing Record 48 of Set 10 | tsabong
# Processing Record 49 of Set 10 | krini
# Processing Record 50 of Set 10 | wajima
# Processing Record 1 of Set 11 | krutinka
# Processing Record 2 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 11 | nemuro
# Processing Record 4 of Set 11 | batagay
# Processing Record 5 of Set 11 | taoudenni
# Processing Record 6 of Set 11 | seduva
# Processing Record 7 of Set 11 | sao joao da barra
# Processing Record 8 of Set 11 | sault sainte marie
# Processing Record 9 of Set 11 | suffolk
# Processing Record 10 of Set 11 | santa fe
# Processing Record 11 of Set 11 | narok
# Processing Record 12 of Set 11 | paamiut
# Processing Record 13 of Set 11 | kapit
# Processing Record 14 of Set 11 | ivanava
# Processing Record 15 of Set 11 | lisakovsk
# Processing Record 16 of Set 11 | irbeyskoye
# Processing Record 17 of Set 11 | jinchang
# Processing Record 18 of Set 11 | jaru
# Processing Record 19 of Set 11 | san quintin
# Processing Record 20 of Set 11 | cusuna
# Processing Record 21 of Set 11 | nara
# Processing Record 22 of Set 11 | leh
# Processing Record 23 of Set 11 | half moon bay
# Processing Record 24 of Set 11 | cozumel
# Processing Record 25 of Set 11 | erenhot
# Processing Record 26 of Set 11 | najran
# Processing Record 27 of Set 11 | dudinka
# Processing Record 28 of Set 11 | rengasdengklok
# Processing Record 29 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 30 of Set 11 | kathu
# Processing Record 31 of Set 11 | sarangani
# Processing Record 32 of Set 11 | whitehorse
# Processing Record 33 of Set 11 | morondava
# Processing Record 34 of Set 11 | arman
# Processing Record 35 of Set 11 | timiryazevskiy
# Processing Record 36 of Set 11 | ambilobe
# Processing Record 37 of Set 11 | maraa
# Processing Record 38 of Set 11 | hit
# Processing Record 39 of Set 11 | poronaysk
# Processing Record 40 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 11 | baisha
# Processing Record 42 of Set 11 | reforma
# Processing Record 43 of Set 11 | liku
# Processing Record 44 of Set 11 | opunake
# Processing Record 45 of Set 11 | sundsvall
# Processing Record 46 of Set 11 | aykhal
# Processing Record 47 of Set 11 | orlik
# Processing Record 48 of Set 11 | nantucket
# Processing Record 49 of Set 11 | dalbandin
# Processing Record 50 of Set 11 | qandala
# Processing Record 1 of Set 12 | mayo
# Processing Record 2 of Set 12 | tianpeng
# Processing Record 3 of Set 12 | ignacio zaragoza
# Processing Record 4 of Set 12 | saint-francois
# Processing Record 5 of Set 12 | gumdag
# Processing Record 6 of Set 12 | bosaso
# Processing Record 7 of Set 12 | inhambane
# Processing Record 8 of Set 12 | rancho palos verdes
# Processing Record 9 of Set 12 | bereda
# Processing Record 10 of Set 12 | osakarovka
# Processing Record 11 of Set 12 | batagay-alyta
# Processing Record 12 of Set 12 | mucuri
# Processing Record 13 of Set 12 | vokhtoga
# Processing Record 14 of Set 12 | clyde river
# Processing Record 15 of Set 12 | hornepayne
# Processing Record 16 of Set 12 | kantunilkin
# Processing Record 17 of Set 12 | belorechensk
# Processing Record 18 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 12 | yangshan
# Processing Record 20 of Set 12 | vanimo
# Processing Record 21 of Set 12 | ahlat
# Processing Record 22 of Set 12 | bonthe
# Processing Record 23 of Set 12 | turochak
# Processing Record 24 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 26 of Set 12 | svetlogorsk
# Processing Record 27 of Set 12 | gazojak
# Processing Record 28 of Set 12 | saint-augustin
# Processing Record 29 of Set 12 | salinopolis
# Processing Record 30 of Set 12 | anshan
# Processing Record 31 of Set 12 | sesheke
# Processing Record 32 of Set 12 | warwick
# Processing Record 33 of Set 12 | kamogawa
# Processing Record 34 of Set 12 | eydhafushi
# Processing Record 35 of Set 12 | beranang
# Processing Record 36 of Set 12 | suruc
# Processing Record 37 of Set 12 | shushenskoye
# Processing Record 38 of Set 12 | waddan
# Processing Record 39 of Set 12 | algeciras
# Processing Record 40 of Set 12 | along
# Processing Record 41 of Set 12 | blacksburg
# Processing Record 42 of Set 12 | sucua
# Processing Record 43 of Set 12 | oistins
# Processing Record 44 of Set 12 | yangjiang
# Processing Record 45 of Set 12 | nhulunbuy
# Processing Record 46 of Set 12 | sete
# Processing Record 47 of Set 12 | turka
# Processing Record 48 of Set 12 | novyy urgal
# Processing Record 49 of Set 12 | linjiang
# Processing Record 50 of Set 12 | paracuru
# Processing Record 1 of Set 13 | alepe
# Processing Record 2 of Set 13 | tazovskiy
# Processing Record 3 of Set 13 | yaan
# Processing Record 4 of Set 13 | dickinson
# Processing Record 5 of Set 13 | baculin
# Processing Record 6 of Set 13 | kieta
# Processing Record 7 of Set 13 | inuvik
# Processing Record 8 of Set 13 | kavieng
# Processing Record 9 of Set 13 | abu zabad
# Processing Record 10 of Set 13 | kattivakkam
# Processing Record 11 of Set 13 | trincomalee
# Processing Record 12 of Set 13 | nalut
# Processing Record 13 of Set 13 | muscat
# Processing Record 14 of Set 13 | codrington
# Processing Record 15 of Set 13 | severnyy
# Processing Record 16 of Set 13 | stromness
# Processing Record 17 of Set 13 | cannes
# Processing Record 18 of Set 13 | imbituba
# Processing Record 19 of Set 13 | broken hill
# Processing Record 20 of Set 13 | abha
# Processing Record 21 of Set 13 | oriximina
# Processing Record 22 of Set 13 | tsienyane
# City not found. Skipping...
# Processing Record 23 of Set 13 | ixtapa
# Processing Record 24 of Set 13 | harjavalta
# Processing Record 25 of Set 13 | abu kamal
# Processing Record 26 of Set 13 | krasavino
# Processing Record 27 of Set 13 | cienfuegos
# Processing Record 28 of Set 13 | high rock
# Processing Record 29 of Set 13 | sohag
# Processing Record 30 of Set 13 | davenport
# Processing Record 31 of Set 13 | berlevag
# Processing Record 32 of Set 13 | bucerias
# Processing Record 33 of Set 13 | nelson
# Processing Record 34 of Set 13 | yeppoon
# Processing Record 35 of Set 13 | channel-port aux basques
# Processing Record 36 of Set 13 | chiang kham
# Processing Record 37 of Set 13 | simao
# Processing Record 38 of Set 13 | piranhas
# Processing Record 39 of Set 13 | westport
# Processing Record 40 of Set 13 | kulhudhuffushi
# Processing Record 41 of Set 13 | umm lajj
# Processing Record 42 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 43 of Set 13 | kazuno
# Processing Record 44 of Set 13 | brae
# Processing Record 45 of Set 13 | maple creek
# Processing Record 46 of Set 13 | coihaique
# Processing Record 47 of Set 13 | ayr
# Processing Record 48 of Set 13 | chulym
# Processing Record 49 of Set 13 | maine-soroa
# Processing Record 50 of Set 13 | zhigansk
# Processing Record 1 of Set 14 | mariental
# Processing Record 2 of Set 14 | altamira
# Processing Record 3 of Set 14 | rio grande
# Processing Record 4 of Set 14 | solnechnyy
# Processing Record 5 of Set 14 | beni
# Processing Record 6 of Set 14 | deming
# Processing Record 7 of Set 14 | hoquiam
# Processing Record 8 of Set 14 | kalmunai
# Processing Record 9 of Set 14 | calbe
# Processing Record 10 of Set 14 | ilebo
# Processing Record 11 of Set 14 | kolno
# Processing Record 12 of Set 14 | manta
# Processing Record 13 of Set 14 | gouyave
# Processing Record 14 of Set 14 | pemberton
# Processing Record 15 of Set 14 | yarmouth
# Processing Record 16 of Set 14 | necochea
# Processing Record 17 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 18 of Set 14 | manbij
# Processing Record 19 of Set 14 | bredy
# Processing Record 20 of Set 14 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 21 of Set 14 | ust-tsilma
# Processing Record 22 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 23 of Set 14 | vaasa
# Processing Record 24 of Set 14 | youkounkoun
# Processing Record 25 of Set 14 | novopskov
# Processing Record 26 of Set 14 | hovd
# Processing Record 27 of Set 14 | harlingen
# Processing Record 28 of Set 14 | bom jesus
# Processing Record 29 of Set 14 | vyshhorod
# Processing Record 30 of Set 14 | comodoro rivadavia
# Processing Record 31 of Set 14 | alice springs
# Processing Record 32 of Set 14 | saint-georges
# Processing Record 33 of Set 14 | puerto lopez
# Processing Record 34 of Set 14 | faya
# Processing Record 35 of Set 14 | coahuayana
# Processing Record 36 of Set 14 | nizhniy baskunchak
# Processing Record 37 of Set 14 | lagoa
# Processing Record 38 of Set 14 | novikovo
# Processing Record 39 of Set 14 | tromso
# Processing Record 40 of Set 14 | waterloo
# Processing Record 41 of Set 14 | baherden
# Processing Record 42 of Set 14 | mangan
# Processing Record 43 of Set 14 | walkerton
# Processing Record 44 of Set 14 | abu dhabi
# Processing Record 45 of Set 14 | yelnya
# Processing Record 46 of Set 14 | touros
# Processing Record 47 of Set 14 | trelew
# Processing Record 48 of Set 14 | itoman
# Processing Record 49 of Set 14 | arys
# Processing Record 50 of Set 14 | poltavka
# Processing Record 1 of Set 15 | olafsvik
# Processing Record 2 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 15 | dire dawa
# Processing Record 4 of Set 15 | rafraf
# Processing Record 5 of Set 15 | marystown
# Processing Record 6 of Set 15 | kingswood
# Processing Record 7 of Set 15 | vila do maio
# Processing Record 8 of Set 15 | san-pedro
# Processing Record 9 of Set 15 | maues
# Processing Record 10 of Set 15 | yabrud
# Processing Record 11 of Set 15 | terrace
# Processing Record 12 of Set 15 | la ronge
# Processing Record 13 of Set 15 | pangody
# Processing Record 14 of Set 15 | linqiong
# Processing Record 15 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 16 of Set 15 | sept-iles
# Processing Record 17 of Set 15 | hailar
# Processing Record 18 of Set 15 | segou
# Processing Record 19 of Set 15 | raudeberg
# Processing Record 20 of Set 15 | zhuhai
# Processing Record 21 of Set 15 | quelimane
# Processing Record 22 of Set 15 | pouebo
# Processing Record 23 of Set 15 | cambyreta
# City not found. Skipping...
# Processing Record 24 of Set 15 | camacha
# Processing Record 25 of Set 15 | andenes
# Processing Record 26 of Set 15 | weinan
# Processing Record 27 of Set 15 | dunstable
# Processing Record 28 of Set 15 | jizan
# Processing Record 29 of Set 15 | barcelona
# Processing Record 30 of Set 15 | winnemucca
# Processing Record 31 of Set 15 | ambulu
# Processing Record 32 of Set 15 | puri
# Processing Record 33 of Set 15 | ngunguru
# Processing Record 34 of Set 15 | kassala
# Processing Record 35 of Set 15 | kjopsvik
# Processing Record 36 of Set 15 | izhma
# Processing Record 37 of Set 15 | maanshan
# Processing Record 38 of Set 15 | vodnyy
# Processing Record 39 of Set 15 | tahta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 686

# %%
# Convert array of dictionaries to Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(15)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Ushuaia      AR -54.8000  -68.3000     31.66        80
# 1            Cherskiy      RU  68.7500  161.3000     47.28        45
# 2            Atherton      GB  53.5237   -2.4935     62.74        88
# 3                Buta      CD   2.7858   24.7300     70.27        99
# 4           Cape Town      ZA -33.9258   18.4232     57.38        81
# 5              Hobart      AU -42.8794  147.3294     46.26        85
# 6   Zverinogolovskoye      RU  54.4586   64.8542     54.81        92
# 7             Odweyne      SO   9.4092   45.0640     70.21        48
# 8            Barcelos      PT  41.5388   -8.6151     68.92        90
# 9      Ribeira Grande      PT  38.5167  -28.7000     73.45        86
# 10    Bambous Virieux      MU -20.3428   57.7575     69.22        88
# 11            Mataura      NZ -46.1927  168.8643     43.48        94
# 12              Airai      TL  -8.9266  125.4092     57.38        85
# 13            Navirai      BR -23.0650  -54.1906     71.49        38
# 14            Rikitea      PF -23.1203 -134.9692     74.10        80
#
#     Cloudiness  Wind Speed Current Description
# 0           75       21.85          light snow
# 1           99       11.86     overcast clouds
# 2           99        3.20     overcast clouds
# 3          100        1.50          light rain
# 4            0        3.00           clear sky
# 5           20        8.05          few clouds
# 6            0        7.47           clear sky
# 7           34       14.29    scattered clouds
# 8           67        1.79       broken clouds
# 9           52        2.01       broken clouds
# 10          40       12.66    scattered clouds
# 11         100        0.98     overcast clouds
# 12          98        3.78     overcast clouds
# 13          19        4.79          few clouds
# 14          94       23.02          light rain

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "C:/Users/19164/Desktop/Data Analytics/Class Modules + Challenges/Unit 6 APIs/Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
